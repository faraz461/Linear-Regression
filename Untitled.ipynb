# %%
import numpy as np
import pandas as pd
data=pd.read_csv("CarPrice_Assignment.csv")
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
import seaborn as sns
sns.pairplot(data)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
sns.distplot(data['price'],color="y")
# Out:
# <AxesSubplot:xlabel='price'>

# %%
sns.jointplot(x="wheelbase",y="price",data=data,kind='kde',color='red')

# %%
plt.figure(figsize=(15,10))
sns.countplot(data['enginelocation'])
# Out:
# <AxesSubplot:xlabel='enginelocation', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(data.enginelocation,data['price'],color=['c'])
# Out:
# <AxesSubplot:xlabel='enginelocation', ylabel='price'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
data['fuelsystem']=lab.fit_transform(data['fuelsystem'])
data['cylindernumber']=lab.fit_transform(data['cylindernumber'])
data['enginetype']=lab.fit_transform(data['enginetype'])
data['enginelocation']=lab.fit_transform(data['enginelocation'])
data['drivewheel']=lab.fit_transform(data['drivewheel'])
data['carbody']=lab.fit_transform(data['carbody'])
data['doornumber']=lab.fit_transform(data['doornumber'])
data['aspiration']=lab.fit_transform(data['aspiration'])
data['fueltype']=lab.fit_transform(data['fueltype'])
data['CarName']=lab.fit_transform(data['CarName'])

# %%
data.head()
# Out:
#    car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0       1          3        2         1           0           1        0
# 1       2          3        3         1           0           1        0
# 2       3          1        1         1           0           1        2
# 3       4          2        4         1           0           0        3
# 4       5          2        5         1           0           0        3
#
#    drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0           2               0       88.6  ...         130           5
# 1           2               0       88.6  ...         130           5
# 2           2               0       94.5  ...         152           5
# 3           1               0       99.8  ...         109           5
# 4           0               0       99.4  ...         136           5
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
# 2       2.68    3.47               9.0         154     5000       19
# 3       3.19    3.40              10.0         102     5500       24
# 4       3.19    3.40               8.0         115     5500       18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
import missingno as msno
msno.dendrogram(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-51756941f876> in <module>
# ----> 1 import missingno as msno
#       2 msno.dendrogram(data)
#
# ModuleNotFoundError: No module named 'missingno'

# %%
sns.boxplot(data['enginesize'],color='red')
# Out:
# <AxesSubplot:xlabel='enginesize'>

# %%
data['enginesize']=data['enginesize'].rank()

# %%
sns.boxplot(data['enginesize'],color='red')
# Out:
# <AxesSubplot:xlabel='enginesize'>

# %%
corr=data.corr()
corr.style.background_gradient(cmap="inferno")
# Out:
# <style  type="text/css" >
# #T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col0,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row1_col1,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row2_col2,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row3_col3,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row4_col4,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row5_col5,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row6_col6,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row7_col7,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row8_col8,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row9_col9,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row10_col10,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row11_col11,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row12_col12,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row13_col13,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row14_col14,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row15_col15,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row16_col16,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row17_col17,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row18_col18,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row19_col19,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row20_col20,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row21_col21,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row22_col22,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row23_col23,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row24_col24,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row25_col25{
#             background-color:  #fcffa4;
#             color:  #000000;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col1,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row5_col11{
#             background-color:  #62146e;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col2{
#             background-color:  #f4f88e;
#             color:  #000000;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col3,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row17_col1,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row25_col12{
#             background-color:  #a02a63;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col4,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row3_col18,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row4_col23,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row5_col13,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row7_col4,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row7_col8,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row15_col14,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row18_col5,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row19_col18{
#             background-color:  #781c6d;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col5,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row16_col1,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row18_col1{
#             background-color:  #67166e;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col6,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row1_col24,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row2_col3,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row2_col6,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row5_col24,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row6_col23,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row7_col5,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row15_col20,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row16_col12{
#             background-color:  #ad305d;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col7,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col25,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row7_col1,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row14_col10,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row14_col17,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row15_col16,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row20_col19{
#             background-color:  #7d1e6d;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col8,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row13_col8,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row19_col22{
#             background-color:  #59106e;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col9,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col11,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col21{
#             background-color:  #a22b62;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col10,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row5_col21,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row6_col13,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row12_col16,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row19_col11,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row20_col9,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row20_col11{
#             background-color:  #c03a51;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col12{
#             background-color:  #c33b4f;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col13,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row1_col21,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row6_col11,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row11_col6,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row12_col25,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row13_col6{
#             background-color:  #b43359;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col14,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row24_col14,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row25_col24{
#             background-color:  #09061f;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col15,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row1_col19{
#             background-color:  #3d0965;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col16,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row8_col17,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row15_col7,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row18_col3,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row18_col12,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row21_col8{
#             background-color:  #ae305c;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col17,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row8_col16,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row20_col12{
#             background-color:  #c43c4e;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col18{
#             background-color:  #c73e4c;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col19,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row3_col0,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row5_col9,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row25_col23{
#             background-color:  #0b0724;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col20,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row4_col17,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row13_col20,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row19_col16{
#             background-color:  #d44842;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col22,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row23_col19{
#             background-color:  #310a5c;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col23,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row1_col17,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row10_col4,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row19_col9,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row19_col17,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row20_col16{
#             background-color:  #a92e5e;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row0_col24,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row5_col23,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row14_col21,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row16_col4,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row20_col25{
#             background-color:  #a82e5f;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row1_col0,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row2_col14,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row17_col14{
#             background-color:  #060419;
#             color:  #f1f1f1;
#         }#T_ba729074_3416_11eb_85dc_eeeccf604ad0row1_col2,#T_ba729074_3416_11eb_85dc_eeeccf604ad0row16_col22{

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(),annot=True,cmap='inferno',mask=np.triu(data.corr(),k=1))
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split,KFold,cross_val_score,GridSearchCV,RandomizedSearchCV
x=data.drop(['car_ID','price'],axis=1)
y=data['price']
xr,xt,yr,yt=train_test_split(x,y,test_size=0.1)

# %%
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.metrics import r2_score,mean_squared_error,mean_squared_log_error,make_scorer
from sklearn.pipeline import make_pipeline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-a1a0ba5d348c> in <module>
#       1 from sklearn.ensemble import RandomForestRegressor
# ----> 2 from xgboost import XGBRegressor
#       3 from lightgbm import LGBMRegressor
#       4 from sklearn.metrics import r2_score,mean_squared_error,mean_squared_log_error,make_scorer
#       5 from sklearn.pipeline import make_pipeline
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
mod=LGBMRegressor(n_estimators=40)
model=make_pipeline(mod)
model.fit(x,y)
print(model)
kfold=KFold(n_splits=5)
score=cross_val_score(model,x,y,cv=kfold)
print(score)
yp=model.predict(xt)
print(r2_score(yt,yp))
print(mean_squared_error(yt,yp))
print(mean_squared_log_error(yt,yp))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-b02e6d0ea661> in <module>
# ----> 1 mod=LGBMRegressor(n_estimators=40)
#       2 model=make_pipeline(mod)
#       3 model.fit(x,y)
#       4 print(model)
#       5 kfold=KFold(n_splits=5)
#
# NameError: name 'LGBMRegressor' is not defined

# %%
mod=RandomForestRegressor(n_estimators=100)
model=make_pipeline(mod)
print(model)
kfold=KFold(n_splits=5)
model.fit(x,y)
score=cross_val_score(model,x,y,cv=kfold)
print(score)
yp=model.predict(xt)
print(r2_score(yt,yp))
print(mean_squared_error(yt,yp))
print(mean_squared_log_error(yt,yp))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-b8c0e0a62408> in <module>
#       1 mod=RandomForestRegressor(n_estimators=100)
# ----> 2 model=make_pipeline(mod)
#       3 print(model)
#       4 kfold=KFold(n_splits=5)
#       5 model.fit(x,y)
#
# NameError: name 'make_pipeline' is not defined

# %%
import pickle

pkl_path = "./Car.pkl"
with open(pkl_path, "wb") as f:
    pickle.dump(model, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-b75a97d74730> in <module>
#       3 pkl_path = "./Car.pkl"
#       4 with open(pkl_path, "wb") as f:
# ----> 5     pickle.dump(model, f)
#
# NameError: name 'model' is not defined

# %%
import pickle
pkl_path = './Car.pkl'
with open(pkl_path, 'rb') as f:
    model = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-22-1d3e62b71cca> in <module>
#       2 pkl_path = './Car.pkl'
#       3 with open(pkl_path, 'rb') as f:
# ----> 4     model = pickle.load(f)
#
# EOFError: Ran out of input

# %%
xgb1 = XGBRegressor()
parameters = {'n_estimators': [500]}

xgb_grid = GridSearchCV(xgb1,parameters,cv = 2)

xgb_grid.fit(x,y)

print(xgb_grid.best_score_)
print(xgb_grid.best_params_)
yp=xgb_grid.predict(xt)
print(r2_score(yt,yp))
print(mean_squared_error(yt,yp))
print(mean_squared_log_error(yt,yp))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-9264311127d6> in <module>
# ----> 1 xgb1 = XGBRegressor()
#       2 parameters = {'n_estimators': [500]}
#       3
#       4 xgb_grid = GridSearchCV(xgb1,parameters,cv = 2)
#       5
#
# NameError: name 'XGBRegressor' is not defined
